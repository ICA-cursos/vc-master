# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Problema de Classificação Multilabel

# %%
import os
import time
import random
import zipfile
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
from skimage import io
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from skimage.transform import resize
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
drive_path = '/content/drive/My Drive/Aula07 - Classificação Multilabel'
os.chdir(drive_path)
# !ls
# Out:
#  celebA_small.csv		     decision_tree_multilabel_celeba.jpg  'prep Multilabel.ipynb'
#  celebA_small.zip		     img_align_celeba.zip		   README.txt
#  classification_report_celeba.json   Multilabel.ipynb			   tree_celeba.jpg

# %%
start_time = time.time()

# Caminhos para os arquivos
images_zip = 'celebA_small.zip'
labels_file = 'celebA_small.csv'
images_folder = images_zip.split('.')[0]

# Trecho de extração comentado, pois demora MUITO e a pasta descompactada já está salva no drive para vocês!
# with zipfile.ZipFile(images_zip, 'r') as zip_ref:
#   zip_ref.extractall(drive_path)

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Execution time: 237.30590772628784 seconds

# %%
# Carregar as classes
labels = pd.read_csv(labels_file, index_col=0)
labels.head()
# Out:
#             Male  Heavy_Makeup  Smiling  Young
# 000001.jpg     0             1        1      1
# 000002.jpg     0             0        1      1
# 000003.jpg     1             0        0      1
# 000004.jpg     0             0        0      1
# 000005.jpg     0             1        0      1

# %% [markdown]
# # Faça análises e treine modelos livremente!
